# %% [markdown]
# **Treinando modelo para detectar fraturas no raio-x**

# %%
# Placa de vídeo disponível
# !nvidia-smi
# Out:
# Sun Dec  8 19:49:17 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install -q roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="czTqBIP5IYASkfFyDuUf")
project = rf.workspace("new-workspace-3jona").project("fracture_detect")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to fracture_detect-2 in yolov11:: 100%|██████████| 5208/5208 [00:00<00:00, 6398.14it/s]

# %%
# !pip install -q ultralytics

# !yolo task=detect mode=train model=yolo11m.pt data=/content/fracture_detect-2/data.yaml epochs=100 imgsz=350 workers=2
# Out:
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
