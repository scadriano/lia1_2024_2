# %% [markdown]
# **Treinando modelo para detecção dos ossos da mão**

# %%
# !nvidia-smi
# Out:
# Fri Dec  6 14:03:21 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="czTqBIP5IYASkfFyDuUf")
project = rf.workspace("nishanth").project("x-ray-bones-detector")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to x-ray-bones-detector-4 in yolov11:: 100%|██████████| 922/922 [00:00<00:00, 8447.15it/s]

# %%
# !pip install -q ultralytics

# !yolo task=detect mode=train model=yolo11m.pt data=/content/x-ray-bones-detector-4/data.yaml epochs=50 imgsz=640 plots=True
# Out:
# ...
# 100% 38.8M/38.8M [00:00<00:00, 374MB/s]
# Ultralytics 8.3.44 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
