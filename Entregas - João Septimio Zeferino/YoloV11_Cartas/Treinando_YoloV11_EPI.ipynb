# %% [markdown]
# Treinamento de modelo usando Yolo V11 - O Roboflow para baixar imagens
#
# Roboflow tem tudo que você precisa para construir e implantar modelos de visão computacional. Conecte o Roboflow em qualquer etapa do pipeline com APIs e SDKs ou use a interface ponta a ponta para automatizar todo o processo, da imagem à inferência. 🚀
#
# Dataset para download das imagens de treinamento de EPIs
#
# https://universe.roboflow.com/roboflow-100/construction-safety-gsnvb/dataset/2

# %%
# Placa de vídeo disponível
# !nvidia-smi
# Out:
# Mon Oct 21 12:46:32 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install -q ultralytics
from ultralytics import YOLO

# !pip install -q roboflow
from roboflow import Roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 876.6/876.6 kB 20.8 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="nPiWbrGDCwWzHNekpUrf")
project = rf.workspace("pokercards-byjc4").project("cards-bx50k-lzmal")
version = project.version(3)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to cards-3 in yolov11:: 100%|██████████| 2028/2028 [00:00<00:00, 4169.20it/s]

# %% [markdown]
# Treinamento

# %%
# !yolo task=detect mode=train model=yolo11n.pt data=/content/cards-3/data.yaml epochs=50 imgsz=640 workers=2
# Out:
# Ultralytics 8.3.18 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
