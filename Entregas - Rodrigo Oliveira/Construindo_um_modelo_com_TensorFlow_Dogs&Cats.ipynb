# %% [markdown]
# <a href="https://colab.research.google.com/github/scadriano/lia1_2024_2/blob/main/Construindo%20Modelo%20com%20TensorFlow/Construindo_um_modelo_com_TensorFlow_Dogs%26Cats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Construindo um Modelo com Tensorflow -  🐶 🐱!**
#
# *Aluno: Rodrigo de Oliveira Ribeiro - Projeto LIA*
#
# **Problema: uma imagem, dizer se é um dog ou um cat.**
#
# Computer Vision; Deep Learning; Machine Learning; Artificial Inteligence! Nada disso faz sentido sem dados, muitos dados (Big Data! 🚀). Para isso, teremos:
#
# * **Treinamento**: 25.000 imagens nomeadas: 12.500 de dogs e 12.500 de cats.
# * **Teste**: 1.000 imagens de dogs e cats.
#
# Usa-se os dados de treino para treinar o algoritmo e então criar o modelo preditivo. Usa-se os dados de teste para confirmar o desempenho do modelo preditivo já treinado, ou seja, apresenta-se ao modelo preditivo dados que ele não viu durante o treinamento, a fim de garantir que ele seja capaz de fazer previsões.
#
# Por fim, o modelo de duas camadas de convolução seguidas de pooling, a camada de flattening, e as camadas totalmente conectadas (Dense), com a função de ativação sigmoid para a saída binária.
#
# **Não há mágica. Há matemática!** 🧙

# %% [markdown]
# **Fonte de dados**
#
# O Kaggle oferece diversos datasets públicos que podem ser usados para você desenvolver seus projetos e incluir no seu portfólio, uma excelente forma de demonstrar suas habilidades em Data Science e Machine Learning. Usaremos como fonte de dados, o famoso [dataset Dogs and Cats](https://www.kaggle.com/c/dogs-vs-cats/data).

# %% [markdown]
# **Carregando os dados de Treino e Teste**

# %%
from IPython.display import Image

# Exibir imagem de um cachorro
Image(filename=r'R:/UFG/LIA/Modelo com TensorFlow/train/dogs/dog.251.jpg')

# %%
from IPython.display import Image

# Exibir imagem de um cachorro
Image(filename=r'R:/UFG/LIA/Modelo com TensorFlow/train/cats/cat.708.jpg')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
Image(filename = 'R:/UFG/LIA/Modelo com TensorFlow/test1//test1/11.jpg')

# %% [markdown]
# **Construindo a Rede Neural Convolucional**
#
# O Keras é uma biblioteca do TensorFlow.

# %%
# %pip install tensorflow
import tensorflow as tf
# Out:
# Requirement already satisfied: tensorflow in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (2.17.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.25.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.66.2)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.24.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.38.4)
# Requirement already satisfied: rich in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2023.11.17)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.2.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.17.0->tensorflow) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rodrigo oliveira\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import keras as K

# %%
# Importar K e suas funções necessárias
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# %%
# Inicializando a Rede Neural Convolucional
classifier = Sequential()

# %%
# 32 features; formato 3x3; Imagens 64x64; Array 3D (RGB).

# Adicionando a Primeira Camada de Convolução
classifier.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))

# Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adicionando a Segunda Camada de Convolução
classifier.add(Conv2D(32, (3, 3), activation = 'relu'))

# Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Flattening - Transformando em 1D
classifier.add(Flatten())

# Full connection
classifier.add(Dense(units = 128, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))

# Compilando a rede
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
# Out:
# c:\Users\Rodrigo Oliveira\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# **Pré-processamento**
#
# Fazer pré-processamento nos dados, em nosso caso as imagens.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Criar o objeto com as regras de pré-processamento
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

# %%
# Pré-processamento das imagens de treino
training_set = train_datagen.flow_from_directory(r'R:\UFG\LIA\Modelo com TensorFlow\train',
                                                 target_size=(64, 64),
                                                 batch_size=32,
                                                 class_mode='binary')
# Out:
# Found 25000 images belonging to 2 classes.

# %% [markdown]
# **Treinamento do Modelo**

# %%
# Executando o treinamento
classifier.fit(training_set,
               steps_per_epoch=5,
               epochs=25)
# Out:
# Epoch 1/25
# c:\Users\Rodrigo Oliveira\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 707ms/step - accuracy: 0.5718 - loss: 0.8040
# Epoch 2/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 618ms/step - accuracy: 0.4959 - loss: 0.7332
# Epoch 3/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 543ms/step - accuracy: 0.5253 - loss: 0.6905
# Epoch 4/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 481ms/step - accuracy: 0.4733 - loss: 0.6962
# Epoch 5/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 508ms/step - accuracy: 0.5146 - loss: 0.6931
# Epoch 6/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 491ms/step - accuracy: 0.5082 - loss: 0.6928
# Epoch 7/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 552ms/step - accuracy: 0.5064 - loss: 0.6919
# Epoch 8/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 567ms/step - accuracy: 0.6223 - loss: 0.6924
# Epoch 9/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 612ms/step - accuracy: 0.5226 - loss: 0.6926
# Epoch 10/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 619ms/step - accuracy: 0.5485 - loss: 0.6906
# Epoch 11/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 534ms/step - accuracy: 0.5523 - loss: 0.6893
# Epoch 12/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 541ms/step - accuracy: 0.6392 - loss: 0.6881
# Epoch 13/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 513ms/step - accuracy: 0.5726 - loss: 0.6844
# Epoch 14/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 509ms/step - accuracy: 0.5201 - loss: 0.6890
# Epoch 15/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 531ms/step - accuracy: 0.4786 - loss: 0.6930
# Epoch 16/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 478ms/step - accuracy: 0.5564 - loss: 0.6829
# Epoch 17/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 505ms/step - accuracy: 0.4946 - loss: 0.6903
# Epoch 18/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 509ms/step - accuracy: 0.6105 - loss: 0.6751
# Epoch 19/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 503ms/step - accuracy: 0.4983 - loss: 0.6956
# Epoch 20/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 440ms/step - accuracy: 0.5150 - loss: 0.6840
# Epoch 21/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 572ms/step - accuracy: 0.5756 - loss: 0.6639
# Epoch 22/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 496ms/step - accuracy: 0.5564 - loss: 0.6985
# Epoch 23/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 483ms/step - accuracy: 0.5680 - loss: 0.6766
# Epoch 24/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 547ms/step - accuracy: 0.5773 - loss: 0.6673
# Epoch 25/25
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 568ms/step - accuracy: 0.5363 - loss: 0.6802

# %% [markdown]
# Treinamento concluído com sucesso! 💪 Observe se ao final de cada época a acurácia aumenta.

# %% [markdown]
# **Teste do Modelo**

# %% [markdown]
# Testar o modelo treinado com imagens que ele ainda não viu. Por fim, verificamos o resultado da previsão e emitimos a informação se a imagem é de um gato ou cachorro.

# %%
import numpy as np
from keras.preprocessing import image
from IPython.display import Image

# Carregando a imagem de teste
test_image = image.load_img(r'K:\OneDrive - Universidade Federal de Goiás\Área de Trabalho\Sem título.jpg', target_size=(64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)

# Fazendo a previsão usando o modelo classifier
result = classifier.predict(test_image)
class_indices = training_set.class_indices

if result[0][0] > 0.5:
    prediction = 'Cachorro.'
    accuracy = round(result[0][0] * 100, 2)  # A saída de previsão é uma probabilidade entre 0 e 1
else:
    prediction = 'Gato.'
    accuracy = round((1 - result[0][0]) * 100, 2)  # A saída de previsão é uma probabilidade entre 0 e 1

# Exibindo a previsão e a acurácia
print("Previsão:", prediction)
print("Acurácia:", accuracy, "%.")

# Exibindo a imagem
Image(filename= r'K:\Área de Trabalho\Sem título.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Previsão: Cachorro.
# Acurácia: 100.0 %.

# %% [markdown]
# **O modelo recebeu uma imagem que nunca tinha visto antes e com base no que aprendeu durante o treinamento, foi capaz de classificar.**
#
# Convertemos a imagem de teste em um vetor de pixels e apresentamos ao modelo.
# O modelo compara o vetor da imagem de teste com seus pesos e então emite a classificação.

# %% [markdown]
# **Melhorias adicionais para este modelo:**
#
# *   Aumentar o número de épocas para 25 para uma aprendizagem mais profunda.
# *   aumentar o redimensionamento da imagem de 64x64 para 256x256.
# *   Aumentar o tamanho do lote de 32 para 64.
# *   Alterar a arquitetura da rede incluindo mais uma camada convolucional.
# *   Avaliar outras métricas do modelo e ajustar os hiperparâmetros de acordo.
# *   Experimentar outros algoritmos de otimização.

# %% [markdown]
# Fim! 🔥
